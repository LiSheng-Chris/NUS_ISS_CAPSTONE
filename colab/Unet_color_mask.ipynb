# %%
import os
import numpy as np
import cv2
from glob import glob
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Conv2D, Activation, BatchNormalization
from tensorflow.keras.layers import UpSampling2D, Input, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau,ModelCheckpoint,CSVLogger
from tensorflow.keras.metrics import Recall, Precision
from tensorflow.keras import backend as K

# %%
print("Tensorflow version: ", tf.__version__)
print(tf.test.gpu_device_name())
# Out:
# Tensorflow version:  2.4.1
# /device:GPU:0

# %%
# Then you’ll see a link, click on that link, allow access
# Copy the code that pops up, paste it in the box, hit enter

from google.colab import drive
drive.mount('/content/gdrive')

# Change working directory to be current folder, please keep ''/content/gdrive/My Drive/XXX' in the path and change XXX to be your own folder.
# The path is case sensitive.
import os
os.chdir('/content/gdrive/My Drive/iss/capstone')
# !ls
# Out:
# Mounted at /content/gdrive
# colab  data

# %%
# set the randomness and make the results reproducible
np.random.seed(42)
tf.random.set_seed(42)

# %%
#hyperparameters 

IMAGE_SIZE = 256
EPOCHS = 36
BATCH = 8
LR = 1e-4
PATH = "CVC-612/"

# %%
#This function loads the images and masks, split them into training, validation and testing dataset

def load_data(path, split=0.1):
    train_x = sorted(glob(os.path.join(path, "images/ZT*")))
    train_y = sorted(glob(os.path.join(path, "masks/mask_ZT*")))
    
    valid_x = sorted(glob(os.path.join(path, "validation/*")))
    valid_y = sorted(glob(os.path.join(path, "masks_val/*")))

    test_x  = sorted(glob(os.path.join(path, "test/*")))
    test_y  = sorted(glob(os.path.join(path, "masks_test/*"))) 

    print('train_x :',len(train_x), 'train_y : ',len(train_y))
    print('valid_x : ', len(valid_x), 'valid_y : ',len(valid_y))
    print('test_x : ', len(test_x), 'test_y : ',len(test_y))

    #total_size = len(images)
    #valid_size = int(split * total_size)
    #test_size = int(split * total_size)

    #train_x, valid_x = train_test_split(images, test_size=valid_size, random_state=42)
    #train_y, valid_y = train_test_split(masks, test_size=valid_size, random_state=42)

    #train_x, test_x = train_test_split(train_x, test_size=test_size, random_state=42)
    #train_y, test_y = train_test_split(train_y, test_size=test_size, random_state=42)

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

# %%
# read the image and mask , resize ,normalize and return RGB image and a grayscale

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x/255.0
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x/255.0
    return x

# %%
#input dataset pipelines

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float64, tf.float64])
    x.set_shape([IMAGE_SIZE, IMAGE_SIZE, 3])
    y.set_shape([IMAGE_SIZE, IMAGE_SIZE, 3])
    return x, y

def tf_dataset(x, y, batch=8):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.repeat()
    return dataset

# %%
#convert to the RGB formart
def read_and_rgb(x):
    x = cv2.imread(x)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    return x

# %%
(train_x, train_y), (valid_x, valid_y), (test_x, test_y)= load_data('./data')

fig = plt.figure(figsize=(15, 15))
a = fig.add_subplot(1, 4, 1)
imgplot = plt.imshow(read_and_rgb(train_x[0]))

a = fig.add_subplot(1, 4, 2)
imgplot = plt.imshow(read_and_rgb(train_x[1]))
imgplot.set_clim(0.0, 0.7)

a = fig.add_subplot(1, 4, 3)
imgplot = plt.imshow(read_and_rgb(train_x[2]))
imgplot.set_clim(0.0, 1.4)

a = fig.add_subplot(1, 4, 4)
imgplot = plt.imshow(read_and_rgb(train_x[3]))
imgplot.set_clim(0.0, 2.1)

fig = plt.figure(figsize=(15, 15))
a = fig.add_subplot(1, 4, 1)
imgplot = plt.imshow(read_and_rgb(train_y[0]))

a = fig.add_subplot(1, 4, 2)
imgplot = plt.imshow(read_and_rgb(train_y[1]))
imgplot.set_clim(0.0, 0.7)

a = fig.add_subplot(1, 4, 3)
imgplot = plt.imshow(read_and_rgb(train_y[2]))
imgplot.set_clim(0.0, 1.4)

a = fig.add_subplot(1, 4, 4)
imgplot = plt.imshow(read_and_rgb(train_y[3]))
imgplot.set_clim(0.0, 1.4)
# Out:
# train_x : 508 train_y :  508
# valid_x :  133 valid_y :  133
# test_x :  245 test_y :  245

# %%
#UNet with pre-trained MobileNetV2

def model():
    inputs = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3), name="input_image")
    
    encoder = MobileNetV2(input_tensor=inputs, weights="imagenet", include_top=False, alpha=0.35)
    skip_connection_names = ["input_image", "block_1_expand_relu", "block_3_expand_relu", "block_6_expand_relu"]
    encoder_output = encoder.get_layer("block_13_expand_relu").output
    
    f = [16, 32, 48, 64]
    x = encoder_output
    for i in range(1, len(skip_connection_names)+1, 1):
        x_skip = encoder.get_layer(skip_connection_names[-i]).output
        x = UpSampling2D((2, 2))(x)
        x = Concatenate()([x, x_skip])
        
        x = Conv2D(f[-i], (3, 3), padding="same")(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
        
        x = Conv2D(f[-i], (3, 3), padding="same")(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
        
    x = Conv2D(3, (1, 1), padding="same")(x)
    x = Activation("sigmoid")(x)
    
    model = Model(inputs, x)
    return model

# %%
# dice coefficient loss
smooth = 1e-15
def dice_coef(y_true, y_pred, smooth=1):
    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    union = K.sum(y_true, axis=[1,2,3]) + K.sum(y_pred, axis=[1,2,3])
    return K.mean( (2. * intersection + smooth) / (union + smooth), axis=0)

def dice_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %%
#build input dataset

train_dataset = tf_dataset(train_x, train_y, batch=BATCH)
valid_dataset = tf_dataset(valid_x, valid_y, batch=BATCH)

# %%
#compile model

model = model()
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-db6effa86b4b> in <module>()
#       1 #compile model
#       2
# ----> 3 model = model()
#       4 model.summary()
#       5
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     940     #   not to any other argument.
#     941     # - setting the SavedModel saving spec.
# --> 942     inputs, args, kwargs = self._split_out_first_arg(args, kwargs)
#     943     input_list = nest.flatten(inputs)
#     944
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/base_layer.py in _split_out_first_arg(self, args, kwargs)
#    3046     else:
#    3047       raise ValueError(
# -> 3048           'The first argument to `Layer.call` must always be passed.')
#    3049     return inputs, args, kwargs
#    3050
#
# ValueError: The first argument to `Layer.call` must always be passed.

# %%
modelname= 'Unet_color_mask'
folderpath      = '/content/gdrive/My Drive/iss/capstone/colab/'
filepath        = folderpath + modelname + ".hdf5"
checkpoint      = ModelCheckpoint(filepath, 
                                  monitor='val_accuracy', 
                                  verbose=0, 
                                  save_best_only=True, 
                                  mode='max')

csv_logger      = CSVLogger(folderpath+modelname +'.csv')                       # Step 2
callbacks_list  = []                                       # Step 3

print("Path to model:", filepath)
print("Path to log:  ", folderpath+modelname+'.csv')
# Out:
# Path to model: /content/gdrive/My Drive/iss/capstone/colab/Unet_color_mask.hdf5
# Path to log:   /content/gdrive/My Drive/iss/capstone/colab/Unet_color_mask.csv

# %%
# Reduce learning rate or Stop training

callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=4),
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=False),
    checkpoint,
    csv_logger
]

# %%
#define the number of batches in an epoch

train_steps = len(train_x)//BATCH
valid_steps = len(valid_x)//BATCH

if len(train_x) % BATCH != 0:
    train_steps += 1
if len(valid_x) % BATCH != 0:
    valid_steps += 1

# %%
opt = tf.keras.optimizers.Nadam(LR)
metrics = [dice_coef, Recall(), 'accuracy']
model.compile(loss=dice_loss, optimizer=opt, metrics=metrics)

# %%
#train the model
model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=EPOCHS,
    steps_per_epoch=train_steps,
    validation_steps=valid_steps,
    callbacks=callbacks
)
# Out:
# Epoch 1/36
# 64/64 [==============================] - 757s 11s/step - loss: -0.5539 - dice_coef: 0.5539 - recall: 0.3906 - accuracy: 0.3257 - val_loss: -0.5319 - val_dice_coef: 0.5323 - val_recall: 0.3281 - val_accuracy: 0.2823
# Epoch 2/36
# 64/64 [==============================] - 128s 2s/step - loss: -0.6210 - dice_coef: 0.6210 - recall: 0.5927 - accuracy: 0.3412 - val_loss: -0.6132 - val_dice_coef: 0.6120 - val_recall: 0.7759 - val_accuracy: 0.2269
# Epoch 3/36
# 64/64 [==============================] - 128s 2s/step - loss: -0.6570 - dice_coef: 0.6570 - recall: 0.7578 - accuracy: 0.2733 - val_loss: -0.6413 - val_dice_coef: 0.6399 - val_recall: 0.8247 - val_accuracy: 0.2138
# Epoch 4/36
# 64/64 [==============================] - 126s 2s/step - loss: -0.6809 - dice_coef: 0.6808 - recall: 0.8072 - accuracy: 0.2342 - val_loss: -0.6526 - val_dice_coef: 0.6512 - val_recall: 0.8432 - val_accuracy: 0.2047
# Epoch 5/36
# 64/64 [==============================] - 126s 2s/step - loss: -0.6958 - dice_coef: 0.6958 - recall: 0.8257 - accuracy: 0.2392 - val_loss: -0.6637 - val_dice_coef: 0.6624 - val_recall: 0.8565 - val_accuracy: 0.2006
# Epoch 6/36
# 64/64 [==============================] - 126s 2s/step - loss: -0.7090 - dice_coef: 0.7090 - recall: 0.8415 - accuracy: 0.2455 - val_loss: -0.6760 - val_dice_coef: 0.6747 - val_recall: 0.8734 - val_accuracy: 0.2013
# Epoch 7/36
# 64/64 [==============================] - 125s 2s/step - loss: -0.7209 - dice_coef: 0.7209 - recall: 0.8545 - accuracy: 0.2504 - val_loss: -0.6883 - val_dice_coef: 0.6871 - val_recall: 0.8951 - val_accuracy: 0.2037
# Epoch 8/36
# 64/64 [==============================] - 125s 2s/step - loss: -0.7319 - dice_coef: 0.7319 - recall: 0.8656 - accuracy: 0.2554 - val_loss: -0.6985 - val_dice_coef: 0.6972 - val_recall: 0.9139 - val_accuracy: 0.2064
# Epoch 9/36
# 64/64 [==============================] - 125s 2s/step - loss: -0.7421 - dice_coef: 0.7421 - recall: 0.8749 - accuracy: 0.2602 - val_loss: -0.7055 - val_dice_coef: 0.7042 - val_recall: 0.9217 - val_accuracy: 0.2089
# Epoch 10/36
# 64/64 [==============================] - 125s 2s/step - loss: -0.7519 - dice_coef: 0.7519 - recall: 0.8828 - accuracy: 0.2655 - val_loss: -0.7102 - val_dice_coef: 0.7089 - val_recall: 0.9244 - val_accuracy: 0.2097
# Epoch 11/36
# 64/64 [==============================] - 126s 2s/step - loss: -0.7609 - dice_coef: 0.7609 - recall: 0.8899 - accuracy: 0.2697 - val_loss: -0.7144 - val_dice_coef: 0.7131 - val_recall: 0.9243 - val_accuracy: 0.2116
# Epoch 12/36
# 64/64 [==============================] - 124s 2s/step - loss: -0.7694 - dice_coef: 0.7694 - recall: 0.8961 - accuracy: 0.2739 - val_loss: -0.7183 - val_dice_coef: 0.7170 - val_recall: 0.9236 - val_accuracy: 0.2133
# Epoch 13/36
# 64/64 [==============================] - 125s 2s/step - loss: -0.7775 - dice_coef: 0.7775 - recall: 0.9013 - accuracy: 0.2778 - val_loss: -0.7227 - val_dice_coef: 0.7214 - val_recall: 0.9215 - val_accuracy: 0.2175
# Epoch 14/36
# 64/64 [==============================] - 125s 2s/step - loss: -0.7852 - dice_coef: 0.7852 - recall: 0.9059 - accuracy: 0.2817 - val_loss: -0.7267 - val_dice_coef: 0.7255 - val_recall: 0.9185 - val_accuracy: 0.2212
# Epoch 15/36
# 64/64 [==============================] - 125s 2s/step - loss: -0.7925 - dice_coef: 0.7925 - recall: 0.9102 - accuracy: 0.2851 - val_loss: -0.7296 - val_dice_coef: 0.7284 - val_recall: 0.9128 - val_accuracy: 0.2224
# Epoch 16/36
# 64/64 [==============================] - 125s 2s/step - loss: -0.7993 - dice_coef: 0.7993 - recall: 0.9141 - accuracy: 0.2882 - val_loss: -0.7329 - val_dice_coef: 0.7319 - val_recall: 0.9055 - val_accuracy: 0.2273
# Epoch 17/36
# 64/64 [==============================] - 126s 2s/step - loss: -0.8058 - dice_coef: 0.8057 - recall: 0.9176 - accuracy: 0.2912 - val_loss: -0.7349 - val_dice_coef: 0.7341 - val_recall: 0.8925 - val_accuracy: 0.2321
# Epoch 18/36
# 64/64 [==============================] - 127s 2s/step - loss: -0.8120 - dice_coef: 0.8120 - recall: 0.9212 - accuracy: 0.2938 - val_loss: -0.7368 - val_dice_coef: 0.7361 - val_recall: 0.8861 - val_accuracy: 0.2335
# Epoch 19/36
# 64/64 [==============================] - 125s 2s/step - loss: -0.8180 - dice_coef: 0.8180 - recall: 0.9244 - accuracy: 0.2964 - val_loss: -0.7389 - val_dice_coef: 0.7382 - val_recall: 0.8843 - val_accuracy: 0.2327
# Epoch 20/36
# 64/64 [==============================] - 125s 2s/step - loss: -0.8241 - dice_coef: 0.8240 - recall: 0.9279 - accuracy: 0.2988 - val_loss: -0.7419 - val_dice_coef: 0.7412 - val_recall: 0.8857 - val_accuracy: 0.2331
# Epoch 21/36
# 64/64 [==============================] - 126s 2s/step - loss: -0.8298 - dice_coef: 0.8297 - recall: 0.9309 - accuracy: 0.3013 - val_loss: -0.7434 - val_dice_coef: 0.7427 - val_recall: 0.8847 - val_accuracy: 0.2310
# Epoch 22/36
# 64/64 [==============================] - 126s 2s/step - loss: -0.8351 - dice_coef: 0.8351 - recall: 0.9335 - accuracy: 0.3033 - val_loss: -0.7446 - val_dice_coef: 0.7438 - val_recall: 0.8846 - val_accuracy: 0.2294
# Epoch 23/36
# 64/64 [==============================] - 127s 2s/step - loss: -0.8403 - dice_coef: 0.8403 - recall: 0.9361 - accuracy: 0.3054 - val_loss: -0.7475 - val_dice_coef: 0.7468 - val_recall: 0.8844 - val_accuracy: 0.2318
# Epoch 24/36
# 64/64 [==============================] - 128s 2s/step - loss: -0.8454 - dice_coef: 0.8454 - recall: 0.9386 - accuracy: 0.3074 - val_loss: -0.7495 - val_dice_coef: 0.7488 - val_recall: 0.8887 - val_accuracy: 0.2294
# Epoch 25/36
# 64/64 [==============================] - 130s 2s/step - loss: -0.8505 - dice_coef: 0.8505 - recall: 0.9410 - accuracy: 0.3097 - val_loss: -0.7518 - val_dice_coef: 0.7514 - val_recall: 0.8779 - val_accuracy: 0.2382
# Epoch 26/36
# 64/64 [==============================] - 125s 2s/step - loss: -0.8553 - dice_coef: 0.8552 - recall: 0.9436 - accuracy: 0.3114 - val_loss: -0.7531 - val_dice_coef: 0.7527 - val_recall: 0.8770 - val_accuracy: 0.2388
# Epoch 27/36
# 64/64 [==============================] - 125s 2s/step - loss: -0.8601 - dice_coef: 0.8601 - recall: 0.9460 - accuracy: 0.3139 - val_loss: -0.7546 - val_dice_coef: 0.7541 - val_recall: 0.8799 - val_accuracy: 0.2353
# Epoch 28/36
# 64/64 [==============================] - 126s 2s/step - loss: -0.8646 - dice_coef: 0.8646 - recall: 0.9483 - accuracy: 0.3157 - val_loss: -0.7586 - val_dice_coef: 0.7582 - val_recall: 0.8832 - val_accuracy: 0.2422
# Epoch 29/36
# 64/64 [==============================] - ETA: 0s - loss: -0.8692 - dice_coef: 0.8692 - recall: 0.9498 - accuracy: 0.3180Epoch 30/36
# 64/64 [==============================] - 125s 2s/step - loss: -0.8735 - dice_coef: 0.8735 - recall: 0.9521 - accuracy: 0.3204 - val_loss: -0.7625 - val_dice_coef: 0.7623 - val_recall: 0.8805 - val_accuracy: 0.2462
# Epoch 31/36
# 64/64 [==============================] - 125s 2s/step - loss: -0.8776 - dice_coef: 0.8776 - recall: 0.9538 - accuracy: 0.3221 - val_loss: -0.7629 - val_dice_coef: 0.7627 - val_recall: 0.8745 - val_accuracy: 0.2461
# Epoch 32/36
# 64/64 [==============================] - 125s 2s/step - loss: -0.8813 - dice_coef: 0.8813 - recall: 0.9552 - accuracy: 0.3237 - val_loss: -0.7596 - val_dice_coef: 0.7597 - val_recall: 0.8410 - val_accuracy: 0.2560
# Epoch 33/36
# 64/64 [==============================] - 125s 2s/step - loss: -0.8831 - dice_coef: 0.8831 - recall: 0.9543 - accuracy: 0.3239 - val_loss: -0.7654 - val_dice_coef: 0.7647 - val_recall: 0.8796 - val_accuracy: 0.2364
# Epoch 34/36
# 64/64 [==============================] - 125s 2s/step - loss: -0.8862 - dice_coef: 0.8862 - recall: 0.9555 - accuracy: 0.3253 - val_loss: -0.7557 - val_dice_coef: 0.7561 - val_recall: 0.8181 - val_accuracy: 0.2605
# Epoch 35/36
# 64/64 [==============================] - 125s 2s/step - loss: -0.8907 - dice_coef: 0.8907 - recall: 0.9579 - accuracy: 0.3273 - val_loss: -0.7668 - val_dice_coef: 0.7669 - val_recall: 0.8549 - val_accuracy: 0.2615
# Epoch 36/36
# 64/64 [==============================] - 126s 2s/step - loss: -0.8950 - dice_coef: 0.8950 - recall: 0.9605 - accuracy: 0.3300 - val_loss: -0.7648 - val_dice_coef: 0.7651 - val_recall: 0.8387 - val_accuracy: 0.2642

# %%
#evaluating the trained model on the test dataset
modelGo     = model()   # This is used for final testing
modelGo.load_weights(filepath)

opt = tf.keras.optimizers.Nadam(LR)
metrics = [dice_coef, Recall(), Precision()]
modelGo.compile(loss=dice_loss, optimizer=opt, metrics=metrics)


test_dataset = tf_dataset(test_x, test_y, batch=BATCH)

test_steps = (len(test_x)//BATCH)
if len(test_x) % BATCH != 0:
    test_steps += 1

modelGo.evaluate(test_dataset, steps=test_steps)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_0.35_224_no_top.h5
# 2023424/2019640 [==============================] - 0s 0us/step
# 31/31 [==============================] - 309s 9s/step - loss: -0.5514 - dice_coef: 0.5514 - recall: 0.3157 - precision: 0.8384
# [-0.5514481067657471, 0.5515210032463074, 0.3169199824333191, 0.83933025598526]

# %%
def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x/255.0
    return x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x/255.0
    return x

def mask_parse(mask):
    mask = np.squeeze(mask)
    mask = [mask, mask, mask]
    mask = np.transpose(mask, (1, 2, 0))
    return mask

# %%
#print result

for i, (x, y) in enumerate(zip(test_x[:10], test_y[:10])):
    x = read_image(x)
    y = read_mask(y)
    #y_pred = modelGo.predict(np.expand_dims(x, axis=0))[0] > 0.5
    y_pred = modelGo.predict(np.expand_dims(x, axis=0))[0]
    h, w, _ = x.shape
    white_line = np.ones((h, 10, 3))

    all_images = [
        x, white_line,
        y, white_line,
        y_pred
    ]
    image = np.concatenate(all_images, axis=1)
    
    fig = plt.figure(figsize=(12, 12))
    a = fig.add_subplot(1, 1, 1)
    imgplot = plt.imshow(image)
