# %%
import os
import numpy as np
import cv2
from glob import glob
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Conv2D, Activation, BatchNormalization
from tensorflow.keras.layers import UpSampling2D, Input, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau,ModelCheckpoint,CSVLogger
from tensorflow.keras.metrics import Recall, Precision
from tensorflow.keras import backend as K

# %%
print("Tensorflow version: ", tf.__version__)
print(tf.test.gpu_device_name())
# Out:
# Tensorflow version:  2.4.1
# /device:GPU:0

# %%
# Then you’ll see a link, click on that link, allow access
# Copy the code that pops up, paste it in the box, hit enter

from google.colab import drive
drive.mount('/content/gdrive')

# Change working directory to be current folder, please keep ''/content/gdrive/My Drive/XXX' in the path and change XXX to be your own folder.
# The path is case sensitive.
import os
os.chdir('/content/gdrive/My Drive/iss/capstone')
# !ls
# Out:
# Mounted at /content/gdrive
# colab  data

# %%
# set the randomness and make the results reproducible
np.random.seed(42)
tf.random.set_seed(42)

# %%
#hyperparameters 

IMAGE_SIZE = 256
EPOCHS = 100
BATCH = 8
LR = 1e-4
PATH = "CVC-612/"

# %%
#This function loads the images and masks, split them into training, validation and testing dataset

def load_data(path, split=0.1):
    train_x = sorted(glob(os.path.join(path, "images/ZT*")))
    train_y = sorted(glob(os.path.join(path, "masks/mask_ZT*")))
    
    valid_x = sorted(glob(os.path.join(path, "validation/*")))
    valid_y = sorted(glob(os.path.join(path, "masks_val/*")))

    test_x  = sorted(glob(os.path.join(path, "test/*")))
    test_y  = sorted(glob(os.path.join(path, "masks_test/*"))) 

    print('train_x :',len(train_x), 'train_y : ',len(train_y))
    print('valid_x : ', len(valid_x), 'valid_y : ',len(valid_y))
    print('test_x : ', len(test_x), 'test_y : ',len(test_y))

    #total_size = len(images)
    #valid_size = int(split * total_size)
    #test_size = int(split * total_size)

    #train_x, valid_x = train_test_split(images, test_size=valid_size, random_state=42)
    #train_y, valid_y = train_test_split(masks, test_size=valid_size, random_state=42)

    #train_x, test_x = train_test_split(train_x, test_size=test_size, random_state=42)
    #train_y, test_y = train_test_split(train_y, test_size=test_size, random_state=42)

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

# %%
# read the image and mask , resize ,normalize and return RGB image and a grayscale

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x/255.0
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x/255.0
    x = np.expand_dims(x, axis=-1)
    return x

# %%
#input dataset pipelines

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float64, tf.float64])
    x.set_shape([IMAGE_SIZE, IMAGE_SIZE, 3])
    y.set_shape([IMAGE_SIZE, IMAGE_SIZE, 1])
    return x, y

def tf_dataset(x, y, batch=8):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.repeat()
    return dataset

# %%
#convert to the RGB formart
def read_and_rgb(x):
    x = cv2.imread(x)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    return x

# %%
(train_x, train_y), (valid_x, valid_y), (test_x, test_y)= load_data('./data')

fig = plt.figure(figsize=(15, 15))
a = fig.add_subplot(1, 4, 1)
imgplot = plt.imshow(read_and_rgb(train_x[0]))

a = fig.add_subplot(1, 4, 2)
imgplot = plt.imshow(read_and_rgb(train_x[1]))
imgplot.set_clim(0.0, 0.7)

a = fig.add_subplot(1, 4, 3)
imgplot = plt.imshow(read_and_rgb(train_x[2]))
imgplot.set_clim(0.0, 1.4)

a = fig.add_subplot(1, 4, 4)
imgplot = plt.imshow(read_and_rgb(train_x[3]))
imgplot.set_clim(0.0, 2.1)

fig = plt.figure(figsize=(15, 15))
a = fig.add_subplot(1, 4, 1)
imgplot = plt.imshow(read_and_rgb(train_y[0]))

a = fig.add_subplot(1, 4, 2)
imgplot = plt.imshow(read_and_rgb(train_y[1]))
imgplot.set_clim(0.0, 0.7)

a = fig.add_subplot(1, 4, 3)
imgplot = plt.imshow(read_and_rgb(train_y[2]))
imgplot.set_clim(0.0, 1.4)

a = fig.add_subplot(1, 4, 4)
imgplot = plt.imshow(read_and_rgb(train_y[3]))
imgplot.set_clim(0.0, 2.1)
# Out:
# train_x : 508 train_y :  508
# valid_x :  133 valid_y :  133
# test_x :  245 test_y :  245

# %%
#UNet with pre-trained MobileNetV2

def model():
    inputs = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3), name="input_image")
    
    encoder = MobileNetV2(input_tensor=inputs, weights="imagenet", include_top=False, alpha=0.35)
    skip_connection_names = ["input_image", "block_1_expand_relu", "block_3_expand_relu", "block_6_expand_relu"]
    encoder_output = encoder.get_layer("block_13_expand_relu").output
    
    f = [16, 32, 48, 64]
    x = encoder_output
    for i in range(1, len(skip_connection_names)+1, 1):
        x_skip = encoder.get_layer(skip_connection_names[-i]).output
        x = UpSampling2D((2, 2))(x)
        x = Concatenate()([x, x_skip])
        
        x = Conv2D(f[-i], (3, 3), padding="same")(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
        
        x = Conv2D(f[-i], (3, 3), padding="same")(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
        
    x = Conv2D(1, (1, 1), padding="same")(x)
    x = Activation("sigmoid")(x)
    
    model = Model(inputs, x)
    return model

# %%
# dice coefficient loss
smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
#build input dataset

train_dataset = tf_dataset(train_x, train_y, batch=BATCH)
valid_dataset = tf_dataset(valid_x, valid_y, batch=BATCH)

# %%
#compile model

model = model()
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-db6effa86b4b> in <module>()
#       1 #compile model
#       2
# ----> 3 model = model()
#       4 model.summary()
#       5
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     940     #   not to any other argument.
#     941     # - setting the SavedModel saving spec.
# --> 942     inputs, args, kwargs = self._split_out_first_arg(args, kwargs)
#     943     input_list = nest.flatten(inputs)
#     944
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/base_layer.py in _split_out_first_arg(self, args, kwargs)
#    3046     else:
#    3047       raise ValueError(
# -> 3048           'The first argument to `Layer.call` must always be passed.')
#    3049     return inputs, args, kwargs
#    3050
#
# ValueError: The first argument to `Layer.call` must always be passed.

# %%
modelname= 'Unet_epcho_increased'
folderpath      = '/content/gdrive/My Drive/iss/capstone/colab/'
filepath        = folderpath + modelname + ".hdf5"
checkpoint      = ModelCheckpoint(filepath, 
                                  monitor='val_accuracy', 
                                  verbose=0, 
                                  save_best_only=True, 
                                  mode='max')

csv_logger      = CSVLogger(folderpath+modelname +'.csv')                       # Step 2
callbacks_list  = []                                       # Step 3

print("Path to model:", filepath)
print("Path to log:  ", folderpath+modelname+'.csv')
# Out:
# Path to model: /content/gdrive/My Drive/iss/capstone/colab/Unet_epcho_increased.hdf5
# Path to log:   /content/gdrive/My Drive/iss/capstone/colab/Unet_epcho_increased.csv

# %%
# Reduce learning rate or Stop training

callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=4),
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=False),
    checkpoint,
    csv_logger
]

# %%
#define the number of batches in an epoch

train_steps = len(train_x)//BATCH
valid_steps = len(valid_x)//BATCH

if len(train_x) % BATCH != 0:
    train_steps += 1
if len(valid_x) % BATCH != 0:
    valid_steps += 1

# %%
opt = tf.keras.optimizers.Nadam(LR)
metrics = [dice_coef, Recall(), 'accuracy']
model.compile(loss=dice_loss, optimizer=opt, metrics=metrics)

# %%
#train the model
model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=EPOCHS,
    steps_per_epoch=train_steps,
    validation_steps=valid_steps,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 64/64 [==============================] - 811s 12s/step - loss: 0.5184 - dice_coef: 0.4816 - recall: 0.1943 - accuracy: 0.1404 - val_loss: 0.5402 - val_dice_coef: 0.4596 - val_recall: 0.0405 - val_accuracy: 0.0310
# Epoch 2/100
# 64/64 [==============================] - 124s 2s/step - loss: 0.3796 - dice_coef: 0.6204 - recall: 0.4990 - accuracy: 0.3113 - val_loss: 0.3827 - val_dice_coef: 0.6163 - val_recall: 0.3837 - val_accuracy: 0.3222
# Epoch 3/100
# 64/64 [==============================] - 124s 2s/step - loss: 0.3279 - dice_coef: 0.6721 - recall: 0.6786 - accuracy: 0.3604 - val_loss: 0.3150 - val_dice_coef: 0.6837 - val_recall: 0.7907 - val_accuracy: 0.3985
# Epoch 4/100
# 64/64 [==============================] - 123s 2s/step - loss: 0.3088 - dice_coef: 0.6912 - recall: 0.7636 - accuracy: 0.3776 - val_loss: 0.2803 - val_dice_coef: 0.7182 - val_recall: 0.9418 - val_accuracy: 0.4253
# Epoch 5/100
# 64/64 [==============================] - 124s 2s/step - loss: 0.2969 - dice_coef: 0.7031 - recall: 0.8004 - accuracy: 0.3852 - val_loss: 0.2550 - val_dice_coef: 0.7432 - val_recall: 0.9881 - val_accuracy: 0.4324
# Epoch 6/100
# 64/64 [==============================] - 124s 2s/step - loss: 0.2874 - dice_coef: 0.7126 - recall: 0.8111 - accuracy: 0.3888 - val_loss: 0.2449 - val_dice_coef: 0.7532 - val_recall: 0.9957 - val_accuracy: 0.4334
# Epoch 7/100
# 64/64 [==============================] - 124s 2s/step - loss: 0.2789 - dice_coef: 0.7211 - recall: 0.8112 - accuracy: 0.3901 - val_loss: 0.2396 - val_dice_coef: 0.7584 - val_recall: 0.9963 - val_accuracy: 0.4337
# Epoch 8/100
# 64/64 [==============================] - 125s 2s/step - loss: 0.2707 - dice_coef: 0.7293 - recall: 0.8059 - accuracy: 0.3903 - val_loss: 0.2365 - val_dice_coef: 0.7615 - val_recall: 0.9963 - val_accuracy: 0.4338
# Epoch 9/100
# 64/64 [==============================] - 123s 2s/step - loss: 0.2632 - dice_coef: 0.7368 - recall: 0.7986 - accuracy: 0.3901 - val_loss: 0.2333 - val_dice_coef: 0.7647 - val_recall: 0.9946 - val_accuracy: 0.4338
# Epoch 10/100
# 64/64 [==============================] - 123s 2s/step - loss: 0.2557 - dice_coef: 0.7443 - recall: 0.7902 - accuracy: 0.3899 - val_loss: 0.2305 - val_dice_coef: 0.7675 - val_recall: 0.9900 - val_accuracy: 0.4336
# Epoch 11/100
# 64/64 [==============================] - 123s 2s/step - loss: 0.2483 - dice_coef: 0.7517 - recall: 0.7811 - accuracy: 0.3896 - val_loss: 0.2274 - val_dice_coef: 0.7706 - val_recall: 0.9873 - val_accuracy: 0.4334
# Epoch 12/100
# 64/64 [==============================] - 123s 2s/step - loss: 0.2411 - dice_coef: 0.7589 - recall: 0.7707 - accuracy: 0.3894 - val_loss: 0.2259 - val_dice_coef: 0.7722 - val_recall: 0.9807 - val_accuracy: 0.4330
# Epoch 13/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.2338 - dice_coef: 0.7662 - recall: 0.7599 - accuracy: 0.3892 - val_loss: 0.2243 - val_dice_coef: 0.7738 - val_recall: 0.9697 - val_accuracy: 0.4319
# Epoch 14/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.2271 - dice_coef: 0.7729 - recall: 0.7522 - accuracy: 0.3890 - val_loss: 0.2221 - val_dice_coef: 0.7760 - val_recall: 0.9706 - val_accuracy: 0.4321
# Epoch 15/100
# 64/64 [==============================] - 123s 2s/step - loss: 0.2206 - dice_coef: 0.7794 - recall: 0.7448 - accuracy: 0.3891 - val_loss: 0.2205 - val_dice_coef: 0.7776 - val_recall: 0.9652 - val_accuracy: 0.4315
# Epoch 16/100
# 64/64 [==============================] - 123s 2s/step - loss: 0.2140 - dice_coef: 0.7860 - recall: 0.7372 - accuracy: 0.3890 - val_loss: 0.2186 - val_dice_coef: 0.7794 - val_recall: 0.9628 - val_accuracy: 0.4313
# Epoch 17/100
# 64/64 [==============================] - 123s 2s/step - loss: 0.2081 - dice_coef: 0.7919 - recall: 0.7294 - accuracy: 0.3885 - val_loss: 0.2173 - val_dice_coef: 0.7807 - val_recall: 0.9666 - val_accuracy: 0.4318
# Epoch 18/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.2019 - dice_coef: 0.7981 - recall: 0.7198 - accuracy: 0.3884 - val_loss: 0.2155 - val_dice_coef: 0.7826 - val_recall: 0.9512 - val_accuracy: 0.4306
# Epoch 19/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.1959 - dice_coef: 0.8041 - recall: 0.7112 - accuracy: 0.3880 - val_loss: 0.2141 - val_dice_coef: 0.7839 - val_recall: 0.9581 - val_accuracy: 0.4313
# Epoch 20/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.1900 - dice_coef: 0.8100 - recall: 0.7023 - accuracy: 0.3880 - val_loss: 0.2130 - val_dice_coef: 0.7850 - val_recall: 0.9577 - val_accuracy: 0.4312
# Epoch 21/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.1842 - dice_coef: 0.8158 - recall: 0.6948 - accuracy: 0.3883 - val_loss: 0.2122 - val_dice_coef: 0.7858 - val_recall: 0.9540 - val_accuracy: 0.4309
# Epoch 22/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.1788 - dice_coef: 0.8212 - recall: 0.6888 - accuracy: 0.3880 - val_loss: 0.2113 - val_dice_coef: 0.7866 - val_recall: 0.9497 - val_accuracy: 0.4304
# Epoch 23/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.1737 - dice_coef: 0.8263 - recall: 0.6840 - accuracy: 0.3881 - val_loss: 0.2101 - val_dice_coef: 0.7880 - val_recall: 0.9426 - val_accuracy: 0.4299
# Epoch 24/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.1687 - dice_coef: 0.8313 - recall: 0.6802 - accuracy: 0.3885 - val_loss: 0.2097 - val_dice_coef: 0.7883 - val_recall: 0.9462 - val_accuracy: 0.4302
# Epoch 25/100
# 64/64 [==============================] - 123s 2s/step - loss: 0.1643 - dice_coef: 0.8357 - recall: 0.6765 - accuracy: 0.3884 - val_loss: 0.2095 - val_dice_coef: 0.7885 - val_recall: 0.9547 - val_accuracy: 0.4312
# Epoch 26/100
# 64/64 [==============================] - 121s 2s/step - loss: 0.1598 - dice_coef: 0.8402 - recall: 0.6718 - accuracy: 0.3887 - val_loss: 0.2082 - val_dice_coef: 0.7900 - val_recall: 0.9295 - val_accuracy: 0.4286
# Epoch 27/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.1559 - dice_coef: 0.8441 - recall: 0.6693 - accuracy: 0.3889 - val_loss: 0.2077 - val_dice_coef: 0.7903 - val_recall: 0.9482 - val_accuracy: 0.4307
# Epoch 28/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.1519 - dice_coef: 0.8481 - recall: 0.6665 - accuracy: 0.3891 - val_loss: 0.2070 - val_dice_coef: 0.7913 - val_recall: 0.9147 - val_accuracy: 0.4271
# Epoch 29/100
# 64/64 [==============================] - 121s 2s/step - loss: 0.1481 - dice_coef: 0.8519 - recall: 0.6648 - accuracy: 0.3895 - val_loss: 0.2059 - val_dice_coef: 0.7924 - val_recall: 0.9212 - val_accuracy: 0.4276
# Epoch 30/100
# 64/64 [==============================] - 121s 2s/step - loss: 0.1445 - dice_coef: 0.8554 - recall: 0.6642 - accuracy: 0.3898 - val_loss: 0.2049 - val_dice_coef: 0.7932 - val_recall: 0.9314 - val_accuracy: 0.4293
# Epoch 31/100
# 64/64 [==============================] - 121s 2s/step - loss: 0.1414 - dice_coef: 0.8586 - recall: 0.6631 - accuracy: 0.3902 - val_loss: 0.2045 - val_dice_coef: 0.7939 - val_recall: 0.9137 - val_accuracy: 0.4269
# Epoch 32/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.1387 - dice_coef: 0.8613 - recall: 0.6634 - accuracy: 0.3904 - val_loss: 0.2029 - val_dice_coef: 0.7954 - val_recall: 0.9175 - val_accuracy: 0.4280
# Epoch 33/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.1360 - dice_coef: 0.8640 - recall: 0.6628 - accuracy: 0.3907 - val_loss: 0.2022 - val_dice_coef: 0.7961 - val_recall: 0.9078 - val_accuracy: 0.4269
# Epoch 34/100
# 64/64 [==============================] - 121s 2s/step - loss: 0.1334 - dice_coef: 0.8666 - recall: 0.6624 - accuracy: 0.3909 - val_loss: 0.2013 - val_dice_coef: 0.7972 - val_recall: 0.9069 - val_accuracy: 0.4270
# Epoch 35/100
# 64/64 [==============================] - 121s 2s/step - loss: 0.1307 - dice_coef: 0.8693 - recall: 0.6622 - accuracy: 0.3915 - val_loss: 0.2006 - val_dice_coef: 0.7979 - val_recall: 0.8988 - val_accuracy: 0.4263
# Epoch 36/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.1289 - dice_coef: 0.8711 - recall: 0.6620 - accuracy: 0.3914 - val_loss: 0.2003 - val_dice_coef: 0.7982 - val_recall: 0.8942 - val_accuracy: 0.4258
# Epoch 37/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.1272 - dice_coef: 0.8728 - recall: 0.6624 - accuracy: 0.3915 - val_loss: 0.2020 - val_dice_coef: 0.7967 - val_recall: 0.8701 - val_accuracy: 0.4235
# Epoch 38/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.1251 - dice_coef: 0.8749 - recall: 0.6621 - accuracy: 0.3918 - val_loss: 0.2003 - val_dice_coef: 0.7983 - val_recall: 0.8823 - val_accuracy: 0.4243
# Epoch 39/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.1228 - dice_coef: 0.8772 - recall: 0.6616 - accuracy: 0.3921 - val_loss: 0.2018 - val_dice_coef: 0.7969 - val_recall: 0.8604 - val_accuracy: 0.4212
# Epoch 40/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.1209 - dice_coef: 0.8791 - recall: 0.6617 - accuracy: 0.3923 - val_loss: 0.1989 - val_dice_coef: 0.7997 - val_recall: 0.8789 - val_accuracy: 0.4242
# Epoch 41/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.1192 - dice_coef: 0.8808 - recall: 0.6615 - accuracy: 0.3923 - val_loss: 0.2054 - val_dice_coef: 0.7934 - val_recall: 0.8280 - val_accuracy: 0.4166
# Epoch 42/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.1177 - dice_coef: 0.8822 - recall: 0.6622 - accuracy: 0.3928 - val_loss: 0.2060 - val_dice_coef: 0.7929 - val_recall: 0.8248 - val_accuracy: 0.4161
# Epoch 43/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.1159 - dice_coef: 0.8841 - recall: 0.6615 - accuracy: 0.3927 - val_loss: 0.2080 - val_dice_coef: 0.7909 - val_recall: 0.8093 - val_accuracy: 0.4131
# Epoch 44/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.1144 - dice_coef: 0.8856 - recall: 0.6619 - accuracy: 0.3931 - val_loss: 0.2049 - val_dice_coef: 0.7940 - val_recall: 0.8206 - val_accuracy: 0.4154
# Epoch 45/100
# 64/64 [==============================] - 123s 2s/step - loss: 0.1141 - dice_coef: 0.8859 - recall: 0.6647 - accuracy: 0.3936 - val_loss: 0.1996 - val_dice_coef: 0.7991 - val_recall: 0.8554 - val_accuracy: 0.4206
# Epoch 46/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.1132 - dice_coef: 0.8868 - recall: 0.6646 - accuracy: 0.3939 - val_loss: 0.2006 - val_dice_coef: 0.7981 - val_recall: 0.8495 - val_accuracy: 0.4194
# Epoch 47/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.1127 - dice_coef: 0.8872 - recall: 0.6642 - accuracy: 0.3941 - val_loss: 0.2018 - val_dice_coef: 0.7969 - val_recall: 0.8429 - val_accuracy: 0.4181
# Epoch 48/100
# 64/64 [==============================] - 123s 2s/step - loss: 0.1124 - dice_coef: 0.8876 - recall: 0.6639 - accuracy: 0.3942 - val_loss: 0.2029 - val_dice_coef: 0.7958 - val_recall: 0.8366 - val_accuracy: 0.4169
# Epoch 49/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.1130 - dice_coef: 0.8870 - recall: 0.6679 - accuracy: 0.3951 - val_loss: 0.2044 - val_dice_coef: 0.7943 - val_recall: 0.8264 - val_accuracy: 0.4152
# Epoch 50/100
# 64/64 [==============================] - 122s 2s/step - loss: 0.1122 - dice_coef: 0.8878 - recall: 0.6650 - accuracy: 0.3946 - val_loss: 0.2057 - val_dice_coef: 0.7930 - val_recall: 0.8192 - val_accuracy: 0.4139

# %%
#evaluating the trained model on the test dataset
modelGo     = model()   # This is used for final testing
modelGo.load_weights(filepath)

opt = tf.keras.optimizers.Nadam(LR)
metrics = [dice_coef, Recall(), Precision()]
modelGo.compile(loss=dice_loss, optimizer=opt, metrics=metrics)


test_dataset = tf_dataset(test_x, test_y, batch=BATCH)

test_steps = (len(test_x)//BATCH)
if len(test_x) % BATCH != 0:
    test_steps += 1

modelGo.evaluate(test_dataset, steps=test_steps)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_0.35_224_no_top.h5
# 2023424/2019640 [==============================] - 0s 0us/step
# 31/31 [==============================] - 307s 9s/step - loss: 0.2142 - dice_coef: 0.7858 - recall: 0.9971 - precision: 1.0000
# [0.21423687040805817, 0.7859305739402771, 0.9989497065544128, 1.0]

# %%
def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x/255.0
    return x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = np.expand_dims(x, axis=-1)
    x = x/255.0
    return x

def mask_parse(mask):
    mask = np.squeeze(mask)
    mask = [mask, mask, mask]
    mask = np.transpose(mask, (1, 2, 0))
    return mask

# %%
#print result

for i, (x, y) in enumerate(zip(test_x[:10], test_y[:10])):
    x = read_image(x)
    y = read_mask(y)
    y_pred = modelGo.predict(np.expand_dims(x, axis=0))[0]
    h, w, _ = x.shape
    white_line = np.ones((h, 10, 3))

    all_images = [
        x, white_line,
        mask_parse(y), white_line,
        mask_parse(y_pred)
    ]
    image = np.concatenate(all_images, axis=1)
    
    fig = plt.figure(figsize=(12, 12))
    a = fig.add_subplot(1, 1, 1)
    imgplot = plt.imshow(image)
